# %% [markdown]
# # Web Scraper

# %% [markdown]
# # JD Extractor

# %% [markdown]
# # Company Info Extractor

# %% [markdown]
# # Data Normaliser

# %% [markdown]
# # CV Reader

# %% [markdown]
# # CV Suggestions

# %% [markdown]
# # CV Alter
